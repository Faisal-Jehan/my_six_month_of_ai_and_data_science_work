# %% [markdown]
# # RNN (Recurrent Neural Network) - LSTM (Long Short Term Memory) - GRU (Gated Recurrent Unit)

# %% [markdown]
# # RNN

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential

# %%
# Generate example data
X = np.random.rand(100, 10, 1)
y = np.random.randint(0, 2, size=(100,))

# %%
X.shape, y.shape
# Out:
# ((100, 10, 1), (100,))

# %%
# Define the model
model = Sequential([
    SimpleRNN(32, input_shape=(10, 1)),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X, y, epochs=10, batch_size=32)

# Evaluate the model
loss, accuracy = model.evaluate(X, y)
print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 2s 8ms/step - loss: 0.6960 - accuracy: 0.4500
# Epoch 2/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6909 - accuracy: 0.4800
# Epoch 3/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6917 - accuracy: 0.5400
# Epoch 4/10
# 4/4 [==============================] - 0s 11ms/step - loss: 0.6915 - accuracy: 0.5200
# Epoch 5/10
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6895 - accuracy: 0.5700
# Epoch 6/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6863 - accuracy: 0.5500
# Epoch 7/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6837 - accuracy: 0.5400
# Epoch 8/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6822 - accuracy: 0.5400
# Epoch 9/10
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6834 - accuracy: 0.5700
# Epoch 10/10
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6854 - accuracy: 0.5500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6849 - accuracy: 0.5500
# Test Loss: 0.6848709583282471
# Test Accuracy: 0.550000011920929

# %% [markdown]
# # LSTM (Long Short Term Memory) is a special kind of RNN, capable of learning long-term dependencies.

# %%
import seaborn as sns 
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.models import Sequential

# %%
# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series 
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()
# Out:
#             value
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %%
# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model
model = Sequential([
    LSTM(32, input_shape=(seq_length, 1)),
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print("Test Loss:", loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Prediction')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 4s 22ms/step - loss: 0.9885
# Epoch 2/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8095
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6747
# Epoch 4/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5411
# Epoch 5/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4432
# Epoch 6/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3483
# Epoch 7/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2739
# Epoch 8/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2177
# Epoch 9/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1913
# Epoch 10/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1801
# Epoch 11/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1877
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1853
# Epoch 13/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1808
# Epoch 14/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1781
# Epoch 15/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1743
# Epoch 16/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1705
# Epoch 17/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1682
# Epoch 18/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1658
# Epoch 19/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1640
# Epoch 20/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.1627
# Epoch 21/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1612
# Epoch 22/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1624
# Epoch 23/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1616
# Epoch 24/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.1598
# Epoch 25/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1584
# Epoch 26/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1571
# Epoch 27/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1562
# Epoch 28/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1553
# Epoch 29/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1548
# Epoch 30/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1535
# Epoch 31/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1527
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1518
# Epoch 33/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1509
# Epoch 34/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1529
# Epoch 35/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1521
# Epoch 36/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1491
# Epoch 37/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1463
# Epoch 38/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1460
# Epoch 39/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1456
# Epoch 40/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1437
# Epoch 41/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1431
# Epoch 42/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1429
# Epoch 43/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1417
# Epoch 44/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1396
# Epoch 45/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1375
# Epoch 46/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1385
# Epoch 47/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1376
# Epoch 48/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1346
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1336
# Epoch 50/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1326
# Epoch 51/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1331
# Epoch 52/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1307
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1276
# Epoch 54/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1259
# Epoch 55/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1240
# Epoch 56/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1230
# Epoch 57/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1217
# Epoch 58/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1197
# Epoch 59/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1170
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1147
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1125
# Epoch 62/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1114
# Epoch 63/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1079
# Epoch 64/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1058
# Epoch 65/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1041
# Epoch 66/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1015
# Epoch 67/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1016
# Epoch 68/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1007
# Epoch 69/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0934
# Epoch 70/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0982
# Epoch 71/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0928
# Epoch 72/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0862
# Epoch 73/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0853
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0835
# Epoch 75/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0894
# Epoch 76/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0841
# Epoch 77/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0773
# Epoch 78/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0782
# Epoch 79/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0745
# Epoch 80/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0764
# Epoch 81/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0693
# Epoch 82/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0698
# Epoch 83/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0671
# Epoch 84/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0679
# Epoch 85/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0658
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0632
# Epoch 87/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625
# Epoch 88/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0613
# Epoch 89/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0599
# Epoch 90/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0584
# Epoch 91/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0591
# Epoch 92/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0583
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0555
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0572
# Epoch 95/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0537
# Epoch 96/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0570
# Epoch 97/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0533
# Epoch 98/100
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0525
# Epoch 99/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0510
# Epoch 100/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0529
# 1/1 [==============================] - 1s 992ms/step - loss: 1.3982
# Test Loss: 1.398180603981018
# 1/1 [==============================] - 1s 909ms/step

# %% [markdown]
# # let's build a simple RNN-based character-level text generator using a sample test. We'll use a sequence-to-sequence prediction approach to predict the next character in a sequence.

# %%
import numpy as np 
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Sample text data 
text = "hello world! this is a sample text example for rnn."
chars = sorted(list(set(text))) # Get unique characters
char_to_int = dict((c, i) for i, c in enumerate(chars))
int_to_char = dict((i, c) for i, c in enumerate(chars))

# Create input-output sequences
seq_length = 10
X = []
y = []

for i in range(len(text) - seq_length):
        seq_in = text[i:i + seq_length]
        seq_out = text[i + seq_length]
        X.append([char_to_int[char] for char in seq_in])
        y.append(char_to_int[seq_out])

X = np.reshape(X, (len(X), seq_length, 1)) / float(len(chars)) # Normalize
y = tf.keras.utils.to_categorical(y)

# Define the model
model = Sequential([
    LSTM(128, input_shape=(X.shape[1], X.shape[2])),
    Dense(len(chars), activation='softmax')
])

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.fit(X, y, epochs=100, batch_size=10, verbose=1)

# Predict a sequence
start = np.random.randint(0, len(X)-1)
pattern = X[start]
print("Seed:")
print("\"", ''.join([int_to_char[int(value*len(chars))] for value in pattern]), "\"")

for i in range(50): # Generate 50 characters
    x = np.reshape(pattern, (1, len(pattern), 1))
    prediction = model.predict(x, verbose=1)
    index = np.argmax(prediction)
    result = int_to_char[index]
    seq_in = [int_to_char[int(value*len(chars))] for value in pattern]
    print(result, end="")
    pattern = np.append(pattern, index/float(len(chars)))
    pattern = pattern[1:len(pattern)]

print("\n")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 3s 11ms/step - loss: 2.9332
# Epoch 2/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.8996
# Epoch 3/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.8729
# Epoch 4/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.8444
# Epoch 5/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7965
# Epoch 6/100
# 5/5 [==============================] - 0s 14ms/step - loss: 2.7657
# Epoch 7/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7448
# Epoch 8/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7431
# Epoch 9/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7540
# Epoch 10/100
# 5/5 [==============================] - 0s 11ms/step - loss: 2.7254
# Epoch 11/100
# 5/5 [==============================] - 0s 12ms/step - loss: 2.7384
# Epoch 12/100
# Epoch 87/100
# 5/5 [==============================] - 0s 15ms/step - loss: 2.6793
# Epoch 88/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6779
# Epoch 89/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.6790
# Epoch 90/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6802
# Epoch 91/100
# 5/5 [==============================] - 0s 18ms/step - loss: 2.6751
# Epoch 92/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6833
# Epoch 93/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6839
# Epoch 94/100
# 5/5 [==============================] - 0s 17ms/step - loss: 2.6842
# Epoch 95/100
# 5/5 [==============================] - 0s 23ms/step - loss: 2.6736
# Epoch 96/100
# 5/5 [==============================] - 0s 21ms/step - loss: 2.6702
# Epoch 97/100
# 5/5 [==============================] - 0s 25ms/step - loss: 2.6552
# Epoch 98/100
# 5/5 [==============================] - 0s 23ms/step - loss: 2.6671
# Epoch 99/100
# 5/5 [==============================] - 0s 20ms/step - loss: 2.6597
# Epoch 100/100
# 5/5 [==============================] - 0s 38ms/step - loss: 2.6563
# Seed:
# " ! this is  "
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# # GRU (Gated Recurrent Unit) is a variation of LSTM. It has fewer parameters than LSTM, as it lacks an output gate.

# %%
import seaborn as sns 
import numpy as np 
import pandas as pd
import tensorflow as tf
from tensorflow.keras.layers import Dense, GRU # Note the change here
from tensorflow.keras.models import Sequential

# Load flight data
flights = sns.load_dataset('flights')

# Convert data to time series 
df = pd.DataFrame({'value': flights['passengers'].values}, index=pd.date_range(start='1949-01-01', end='1960-12-01', freq='MS'))
df.head()

# Split data into training and testing sets
train_size = int(len(df) * 0.8)
train_data, test_data = df.iloc[:train_size], df.iloc[train_size:]

# Normalize the data
train_mean = train_data.mean()
train_std = train_data.std()
train_data = (train_data - train_mean) / train_std
test_data = (test_data - train_mean) / train_std

# Convert data to sequences
def to_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length-1):
        X_seq = data[i:(i+seq_length)].values
        X.append(X_seq)
        y_seq = data.iloc[i+seq_length].values[0]
        y.append(y_seq)
    return np.array(X), np.array(y)

seq_length = 12
X_train, y_train = to_sequences(train_data, seq_length)
X_test, y_test = to_sequences(test_data, seq_length)

# Reshape input to be (samples, time steps, features)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define the model using GRU
model = Sequential([
    GRU(32, input_shape=(seq_length, 1)), # Note the change here
    Dense(1)
])

# Compile the model
model.compile(optimizer='adam', loss='mse')

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32)

# Evaluate the model
loss = model.evaluate(X_test, y_test)
print("Test Loss:", loss)

# Make predictions on test data
y_pred = model.predict(X_test)

# Plot the predictions and actual values
import matplotlib.pyplot as plt
plt.plot(test_data.index[seq_length+1:], y_test, label='Actual')
plt.plot(test_data.index[seq_length+1:], y_pred, label='Predicted')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 9ms/step - loss: 0.2234
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1740
# Epoch 3/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1458
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1392
# Epoch 5/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1431
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1398
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1354
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1320
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1286
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1284
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1287
# Epoch 12/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1273
# Epoch 13/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1257
# Epoch 14/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1215
# Epoch 15/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1178
# Epoch 16/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1156
# Epoch 17/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1155
# Epoch 18/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1139
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1105
# Epoch 20/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1081
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1069
# Epoch 22/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.1061
# Epoch 23/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1049
# Epoch 24/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1023
# Epoch 25/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1001
# Epoch 26/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0991
# Epoch 27/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0991
# Epoch 28/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0964
# Epoch 29/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0937
# Epoch 30/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0925
# Epoch 31/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0915
# Epoch 32/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0895
# Epoch 33/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0866
# Epoch 34/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0842
# Epoch 35/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0842
# Epoch 36/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0822
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0793
# Epoch 38/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0783
# Epoch 39/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0766
# Epoch 40/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0752
# Epoch 41/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0738
# Epoch 42/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0722
# Epoch 43/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0708
# Epoch 44/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0699
# Epoch 45/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0696
# Epoch 46/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0696
# Epoch 47/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0663
# Epoch 48/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0650
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0625
# Epoch 50/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0646
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0613
# Epoch 52/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0671
# Epoch 53/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0660
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0612
# Epoch 55/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0624
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0608
# Epoch 57/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0640
# Epoch 58/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0615
# Epoch 59/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0583
# Epoch 60/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0609
# Epoch 61/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0580
# Epoch 62/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0554
# Epoch 63/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0563
# Epoch 64/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0557
# Epoch 65/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0547
# Epoch 66/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0553
# Epoch 67/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0547
# Epoch 68/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0564
# Epoch 69/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0556
# Epoch 70/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0531
# Epoch 71/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0528
# Epoch 72/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0524
# Epoch 73/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0521
# Epoch 74/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0543
# Epoch 75/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0532
# Epoch 76/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0520
# Epoch 77/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0553
# Epoch 78/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0532
# Epoch 79/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0504
# Epoch 80/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0501
# Epoch 81/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0513
# Epoch 82/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0502
# Epoch 83/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0508
# Epoch 84/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0519
# Epoch 85/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0516
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0475
# Epoch 87/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0493
# Epoch 88/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0511
# Epoch 89/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0471
# Epoch 90/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0462
# Epoch 91/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0483
# Epoch 92/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0457
# Epoch 93/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0488
# Epoch 94/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0465
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0514
# Epoch 96/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0474
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0464
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0462
# Epoch 99/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0433
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0475
# 1/1 [==============================] - 1s 647ms/step - loss: 0.7583
# Test Loss: 0.7583465576171875
# 1/1 [==============================] - 1s 536ms/step

# %% [markdown]
# # Completed

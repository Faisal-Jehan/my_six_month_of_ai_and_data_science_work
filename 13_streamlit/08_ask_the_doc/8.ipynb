# %%
# Import necessary libraries
import streamlit as st
from langchain.llms import OpenAI
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
import io
import PyPDF2
import docx

# Function to generate response based on the uploaded file and user query
def generate_response(uploaded_file, openai_api_key, query_text):
    # Load document if file is uploaded
    if uploaded_file is not None:
        try:
            # Check file type and extract text accordingly
            if uploaded_file.type == 'application/pdf':
                # Handle PDF file
                pdf_reader = PyPDF2.PdfReader(io.BytesIO(uploaded_file.read()))
                documents = [pdf_reader.pages[i].extract_text() for i in range(len(pdf_reader.pages))]
            elif uploaded_file.type == 'application/vnd.openxmlformats-officedocument.wordprocessingml.document':
                # Handle Word document
                doc_reader = docx.Document(io.BytesIO(uploaded_file.read()))
                documents = [para.text for para in doc_reader.paragraphs]
            else:
                # Default to plain text extraction
                documents = [uploaded_file.read().decode()]
            
            # Split documents into chunks
            text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
            texts = text_splitter.create_documents(documents)
            
            # Initialize embeddings
            embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key)
            
            # Create a vector store from documents
            db = Chroma.from_documents(texts, embeddings)
            
            # Create retriever interface
            retriever = db.as_retriever()
            
            # Create and run QA chain
            qa = RetrievalQA.from_chain_type(llm=OpenAI(openai_api_key=openai_api_key), chain_type='stuff', retriever=retriever)
            
            # Return the QA response
            return qa.run(query_text)
        
        except Exception as e:
            st.error(f"An error occurred: {str(e)}")
            return None

# Streamlit UI setup
# Page title
st.set_page_config(page_title='🦜🔗 Ask the Doc App')
st.title('🦜🔗 Ask the Doc App')

# File upload widget to accept txt, pdf, and docx files
uploaded_file = st.file_uploader('Upload an article', type=['txt', 'pdf', 'docx'])

# Query text input
query_text = st.text_input('Enter your question:', placeholder='Please provide a short summary.', disabled=not uploaded_file)

# Input form for API key and query submission
result = []
with st.form('myform', clear_on_submit=True):
    openai_api_key = st.text_input('OpenAI API Key', type='password', disabled=not (uploaded_file and query_text))
    submitted = st.form_submit_button('Submit', disabled=not(uploaded_file and query_text))
    if submitted and openai_api_key:
        with st.spinner('Searching for answers...'):
            response = generate_response(uploaded_file, openai_api_key, query_text)
            result.append(response)

# Display the response
if len(result):
    st.info(result[0])

# %%
pip install chromadb
# Out:
# Collecting chromadb
#   Using cached chromadb-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=2.28 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (2.32.3)
# Requirement already satisfied: pydantic>=1.9 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (2.7.2)
# Collecting chroma-hnswlib==0.7.3 (from chromadb)
#   Using cached chroma-hnswlib-0.7.3.tar.gz (31 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting fastapi>=0.95.2 (from chromadb)
#   Using cached fastapi-0.111.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Using cached posthog-3.5.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (4.11.0)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Using cached onnxruntime-1.18.0-cp312-cp312-win_amd64.whl.metadata (4.4 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Using cached opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Using cached opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (4.66.4)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Using cached grpcio-1.64.1-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-4.1.3-cp39-abi3-win_amd64.whl.metadata (9.8 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-30.1.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (8.3.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-4.1.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from chromadb) (3.10.3)
# Requirement already satisfied: packaging>=19.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from build>=1.0.3->chromadb) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi>=0.95.2->chromadb)
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi>=0.95.2->chromadb)
#   Using cached fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: jinja2>=2.11.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from fastapi>=0.95.2->chromadb) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi>=0.95.2->chromadb)
#   Using cached python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi>=0.95.2->chromadb)
#   Using cached ujson-5.10.0-cp312-cp312-win_amd64.whl.metadata (9.5 kB)
# Collecting email_validator>=2.0.0 (from fastapi>=0.95.2->chromadb)
#   Using cached email_validator-2.1.1-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Using cached google_auth-2.30.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.1)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: protobuf in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.3)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.12.1-py3-none-any.whl.metadata (12 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (7.1.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached googleapis_common_protos-1.63.1-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Using cached opentelemetry_proto-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached opentelemetry_util_http-0.46b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (69.5.1)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic>=1.9->chromadb) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests>=2.28->chromadb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests>=2.28->chromadb) (3.7)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.23.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from typer>=0.9.0->chromadb) (13.7.1)
# Requirement already satisfied: h11>=0.8 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.1-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached watchfiles-0.22.0-cp312-none-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached websockets-12.0-cp312-cp312-win_amd64.whl.metadata (6.8 kB)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi>=0.95.2->chromadb)
#   Using cached dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.3)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: anyio in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from httpx>=0.23.0->fastapi>=0.95.2->chromadb) (1.3.1)
# Requirement already satisfied: filelock in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jinja2>=2.11.2->fastapi>=0.95.2->chromadb) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb) (2.18.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4.0,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.4.1-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb) (0.1.2)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.0-py2.py3-none-any.whl.metadata (8.3 kB)
# Using cached chromadb-0.5.0-py3-none-any.whl (526 kB)
# Using cached bcrypt-4.1.3-cp39-abi3-win_amd64.whl (158 kB)
# Using cached build-1.2.1-py3-none-any.whl (21 kB)
# Using cached fastapi-0.111.0-py3-none-any.whl (91 kB)
# Using cached grpcio-1.64.1-cp312-cp312-win_amd64.whl (4.1 MB)
# Using cached kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
# Using cached mmh3-4.1.0-cp312-cp312-win_amd64.whl (31 kB)
# Using cached onnxruntime-1.18.0-cp312-cp312-win_amd64.whl (5.6 MB)
# Using cached opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Using cached opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Using cached opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
# Using cached opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Using cached posthog-3.5.0-py2.py3-none-any.whl (41 kB)
# Using cached tokenizers-0.19.1-cp312-none-win_amd64.whl (2.2 MB)
# Using cached typer-0.12.3-py3-none-any.whl (47 kB)
# Using cached uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached email_validator-2.1.1-py3-none-any.whl (30 kB)
# Using cached fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Using cached google_auth-2.30.0-py2.py3-none-any.whl (193 kB)
# Using cached googleapis_common_protos-1.63.1-py2.py3-none-any.whl (229 kB)
# Using cached httptools-0.6.1-cp312-cp312-win_amd64.whl (55 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Using cached python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached ujson-5.10.0-cp312-cp312-win_amd64.whl (42 kB)
# Using cached watchfiles-0.22.0-cp312-none-win_amd64.whl (280 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Using cached websockets-12.0-cp312-cp312-win_amd64.whl (124 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Using cached flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Using cached pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached sympy-1.12.1-py3-none-any.whl (5.7 MB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached dnspython-2.6.1-py3-none-any.whl (307 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached pyasn1_modules-0.4.0-py3-none-any.whl (181 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Using cached wrapt-1.16.0-cp312-cp312-win_amd64.whl (37 kB)
# Using cached pyasn1-0.6.0-py2.py3-none-any.whl (85 kB)
# Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml): started
#   Building wheel for chroma-hnswlib (pyproject.toml): finished with status 'error'
# Failed to build chroma-hnswlib
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for chroma-hnswlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [5 lines of output]
#       running bdist_wheel
#       running build
#       running build_ext
#       building 'hnswlib' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for chroma-hnswlib
# ERROR: Could not build wheels for chroma-hnswlib, which is required to install pyproject.toml-based projects

# %%
try:
    import chromadb
    print("chromadb is installed and can be imported.")
except ImportError:
    print("chromadb is not installed.")
# Out:
# chromadb is not installed.

# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (0.2.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.2.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.1.67)
# Requirement already satisfied: numpy<2,>=1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (2.7.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
try:
    from langchain.llms import OpenAI
    print("langchain is installed and can be imported.")
except ImportError:
    print("langchain is not installed.")
# Out:
# langchain is installed and can be imported.

# %%
pip install streamlit langchain PyPDF2 python-docx
# Out:
# Requirement already satisfied: streamlit in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (1.35.0)
# Requirement already satisfied: langchain in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (0.2.1)
# Requirement already satisfied: PyPDF2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (3.0.1)
# Requirement already satisfied: python-docx in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (0.8.11)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=16.8 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (10.3.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (4.25.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (8.3.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from streamlit) (4.0.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.2.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.2.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (0.1.67)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain) (2.7.2)
# Requirement already satisfied: lxml>=2.3.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from python-docx) (5.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jinja2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from altair<6,>=4.0->streamlit) (4.22.0)
# Requirement already satisfied: toolz in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: colorama in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langchain-core<0.3.0,>=0.2.0->langchain) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from pydantic<3,>=1->langchain) (2.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain) (2.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\ok\miniconda3\envs\streamlit_env\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip show chromadb
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: chromadb

# %%
import Chromadb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import Chromadb
#
# ModuleNotFoundError: No module named 'Chromadb'
